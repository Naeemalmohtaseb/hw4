# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.genfromtxt('../data.txt').reshape([-1,3,3])

# %%
X = data[:,:,0]
Y = data[:,:,1]

# %%
plt.plot(X[:,0], Y[:,0], '-',  lw=3)
plt.plot(X[:,1], Y[:,1], '--', lw=2)
plt.plot(X[:,2], Y[:,2], ':',  lw=1)
